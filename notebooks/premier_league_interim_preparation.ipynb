# %% [markdown]
# # Premier league interim data preparation

# %%
import sys
import os
import pandas as pd

# Add the project root to the Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
    
from football_predictions.data.tools import convert_date as cd

# %%
# Load the data
pl_combined_df = pd.read_csv('../data/raw/premier_league/premier_league_combined.csv')
pl_combined_df
# Out:
#      Div        Date   Time     HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0     E0  11/08/2023  20:00      Burnley        Man City     0     3   A
# 1     E0  12/08/2023  12:30      Arsenal   Nott'm Forest     2     1   H
# 2     E0  12/08/2023  15:00  Bournemouth        West Ham     1     1   D
# 3     E0  12/08/2023  15:00     Brighton           Luton     4     1   H
# 4     E0  12/08/2023  15:00      Everton          Fulham     0     1   A
# ...   ..         ...    ...          ...             ...   ...   ...  ..
# 3035  E0    21/05/17    NaN    Liverpool   Middlesbrough     3     0   H
# 3036  E0    21/05/17    NaN   Man United  Crystal Palace     2     0   H
# 3037  E0    21/05/17    NaN  Southampton           Stoke     0     1   A
# 3038  E0    21/05/17    NaN      Swansea       West Brom     2     1   H
# 3039  E0    21/05/17    NaN      Watford        Man City     0     5   A
#
#       HTHG  HTAG  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  \
# ...

# %%
# Convert the date column to common format
pl_combined_df['Date'] = pl_combined_df['Date'].apply(cd.convert_date)
pl_combined_df
# Out:
#      Div        Date   Time     HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0     E0  11/08/2023  20:00      Burnley        Man City     0     3   A
# 1     E0  12/08/2023  12:30      Arsenal   Nott'm Forest     2     1   H
# 2     E0  12/08/2023  15:00  Bournemouth        West Ham     1     1   D
# 3     E0  12/08/2023  15:00     Brighton           Luton     4     1   H
# 4     E0  12/08/2023  15:00      Everton          Fulham     0     1   A
# ...   ..         ...    ...          ...             ...   ...   ...  ..
# 3035  E0  21/05/2017    NaN    Liverpool   Middlesbrough     3     0   H
# 3036  E0  21/05/2017    NaN   Man United  Crystal Palace     2     0   H
# 3037  E0  21/05/2017    NaN  Southampton           Stoke     0     1   A
# 3038  E0  21/05/2017    NaN      Swansea       West Brom     2     1   H
# 3039  E0  21/05/2017    NaN      Watford        Man City     0     5   A
#
#       HTHG  HTAG  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  \
# ...
